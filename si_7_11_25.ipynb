# %%
def find_area(length, width):
    area=length*width
    return area

#print(find_area(9, 6))

# %%
my_num3=4
print(my_num3)
# Out:
# 4

# %%
def square(x):
    num_squared=x*x
    return num_squared

#print(square(20))
